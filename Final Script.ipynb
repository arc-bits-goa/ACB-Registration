# %%
import numpy as np
import pandas as pd
import csv

# %%
# global degree_data=pd.DataFrame
# global degree_courses=pd.DataFrame
# global degree_students=pd.DataFrame

# %%
#main("Finance")
# Out:
# /home/vinayak/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:8: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
# [['2014B1A40787G', 'ECON F212', 'FIN F315', 'ECON F413', 'FIN F311', 'FIN F313'], ['2014B5A30789G', 'ECON F212', 'ECON F315', 'ECON F413', 'FIN F414', 'FIN F311', 'ECON F412'], ['2014B1A30709G', 'ECON F212', 'ECON F315', 'ECON F241', 'ECON F412'], ['2015A1PS0620G', 'ECON F212', 'ECON F315', 'FIN F414', 'FIN F311', 'FIN F313'], ['2015A3PS0193G', 'ECON F212', 'ECON F315', 'FIN F414', 'FIN F311', 'FIN F313', 'ECON F412'], ['2015B4A70469G'], ['2015A3PS0256G', 'ECON F212', 'FIN F315', 'FIN F311'], ['2015A1PS0643G', 'ECON F212', 'ECON F315', 'FIN F414', 'FIN F311', 'FIN F313'], ['2015A1PS0693G', 'ECON F212', 'FIN F315', 'FIN F311', 'FIN F313'], ['2015A3PS0248G', 'ECON F212', 'ECON F315', 'FIN F414', 'FIN F311', 'FIN F313'], ['2015A4PS0180G', 'ECON F212', 'ECON F315', 'ECON F355', 'FIN F311', 'FIN F313'], ['2015A7PS0103G', 'ECON F212', 'FIN F315', 'ECON F355', 'FIN F311', 'FIN F313'], ['2015A8PS0510G', 'ECON F212', 'FIN F315'], ['2015A7PS0095G', 'ECON F212', 'FIN F315', 'ECON F241', 'FIN F311', 'FIN F313'], ['2015A3PS0238G', 'ECON F212', 'ECON F315', 'FIN F414', 'FIN F311', 'FIN F313'], ['2015A8PS0480G', 'ECON F212', 'ECON F315', 'FIN F414', 'FIN F311', 'FIN F313'], ['2015A3PS0184G', 'ECON F212', 'FIN F315', 'ECON F412'], ['2015A7PS0099G', 'ECON F212', 'ECON F315', 'FIN F311'], ['2015A8PS0392G', 'ECON F212', 'ECON F315', 'FIN F311', 'FIN F313'], ['2015A7PS0023G'], ['2015A1PS0684G', 'ECON F212', 'ECON F315', 'FIN F414', 'FIN F311', 'FIN F313'], ['2015A8PS0441G', 'ECON F212', 'ECON F315', 'ECON F355', 'FIN F414', 'FIN F311', 'FIN F313'], ['2015A4PS0279G', 'ECON F212', 'ECON F312', 'FIN F311', 'FIN F313'], ['2015A7PS0038G', 'ECON F212', 'FIN F315', 'ECON F355', 'FIN F311', 'ECON F412'], ['2015A3PS0283G', 'ECON F212', 'FIN F311'], ['2015A4PS0199G', 'ECON F212', 'ECON F315', 'ECON F312', 'ECON F355', 'FIN F311', 'FIN F313'], ['2015A3PS0214G', 'ECON F212', 'ECON F315', 'FIN F414', 'FIN F311', 'FIN F313'], ['2014B4A70782G', 'FIN F315', 'ECON F412'], ['2015A4PS0331G', 'ECON F212', 'ECON F315', 'ECON F355', 'FIN F311'], ['2015A4PS0346G', 'ECON F212', 'FIN F315'], ['2015A4PS0272G', 'ECON F212', 'FIN F315', 'ECON F355', 'FIN F311', 'FIN F313'], ['2015A3PS0235G', 'ECON F212', 'ECON F315', 'FIN F414', 'FIN F311', 'FIN F313'], ['2015A7PS0032G', 'ECON F212', 'FIN F315', 'FIN F311', 'ECON F412'], ['2015A3PS0181G', 'ECON F315', 'FIN F414', 'FIN F311', 'FIN F313'], ['2015A8PS0420G'], ['2015A1PS0710G', 'ECON F212', 'FIN F414', 'FIN F311'], ['2015A3PS0260G', 'ECON F212', 'ECON F315', 'ECON F355', 'FIN F311', 'FIN F313'], ['2015B1A30766G', 'ECON F212', 'ECON F355'], ['2015A8PS0417G', 'ECON F212', 'ECON F315', 'FIN F414', 'FIN F311', 'FIN F313'], ['2015A1PS0613G', 'ECON F212', 'ECON F315', 'FIN F414', 'FIN F311', 'FIN F313'], ['2015A3PS0222G', 'ECON F212', 'ECON F315', 'FIN F414', 'FIN F311', 'ECON F412'], ['2015A8PS0475G'], ['2015A4PS0247G', 'ECON F212', 'FIN F315', 'ECON F355', 'FIN F311', 'FIN F313'], ['2015A4PS0257G', 'ECON F212', 'FIN F315', 'ECON F355', 'FIN F311', 'FIN F313'], ['2015A8PS0427G', 'FIN F311', 'FIN F313'], ['2015A4PS0205G', 'ECON F212', 'FIN F315', 'ECON F355', 'FIN F311', 'FIN F313'], ['2015A4PS0147G'], ['2015A7PS0101G', 'ECON F212', 'ECON F315', 'ECON F355', 'FIN F311', 'FIN F313'], ['2015A1PS0657G', 'ECON F212', 'ECON F315', 'FIN F414', 'FIN F311', 'FIN F313'], ['2015A1PS0587G', 'ECON F212', 'ECON F315', 'FIN F311'], ['2015A3PS0277G', 'ECON F212', 'ECON F315', 'ECON F312', 'FIN F311', 'FIN F313'], ['2015A3PS0237G', 'ECON F212', 'FIN F311', 'ECON F412'], ['2016A7PS0057G', 'ECON F212', 'FIN F311'], ['2016A8PS0411G', 'ECON F212', 'FIN F315', 'ECON F355', 'FIN F311', 'FIN F313'], ['2016A1PS0701G', 'ECON F212', 'FIN F311', 'FIN F313'], ['2016A1PS0551G', 'ECON F212', 'FIN F315', 'FIN F311', 'FIN F313'], ['2016A7PS0784G', 'ECON F212', 'ECON F315', 'FIN F311', 'FIN F313'], ['2016A7PS0098G', 'ECON F212', 'FIN F311', 'FIN F313'], ['2016A4PS0175G', 'ECON F212', 'FIN F311', 'FIN F313'], ['2016A4PS0329G', 'ECON F212', 'ECON F355', 'FIN F311', 'F ...
# ('Finance',
#  1                                            ECON F212 ECON F315 FIN F315  \
#  (2014B1A40787G, Parth Madan)                         B                  C
#  (2014B5A30789G, Rikkin Majjani)                     A-         B
#  (2014B1A30709G, HEER JOISHER)                        A         B
#  (2015A1PS0620G, SHIVYAM RASTOGI )                   A-         A
#  (2015A3PS0193G, DEEPANSHU KAUSHIK )                 A-         A
#  (2015B4A70469G, VINEET AGARWAL )
#  (2015A3PS0256G, SAUMYA RAJ )                        A-                  B
#  (2015A1PS0643G, AYUSH MITTAL )                       B        A-
#  (2015A1PS0693G, AMANDEEP SINGH )                     C                  D
#  (2015A3PS0248G, AMRITESH KUMAR )                    B-         B
#  (2015A4PS0180G, ADITYA JHA )                        A-         C
#  (2015A7PS0103G, LAV VIJAYVARGIYA )                  A-                 A-
#  (2015A8PS0510G, FADNAVIS RUTVIK SHAILENDRA )         C                  C
#  (2015A7PS0095G, SHILPA RAJU )                        C                  A
#  (2015A3PS0238G, SHUBHAM SINGLA )                    A-        A-
#  (2015A8PS0480G, SHIVANI NEEMA )                      B         C
#  (2015A3PS0184G, SANSKRITI SHRIVASTAVA )              C                  B
#  (2015A7PS0099G, SHUBHANK MAHESHWARI )                B         B
#  (2015A8PS0392G, VISHAL ASNANI )                      C         C
#  (2015A7PS0023G, SAMARTH MITTAL )
#  (2015A1PS0684G, RAKTIM ROYCHOUDHURY )                C        B-
#  (2015A8PS0441G, AKSHAT BUDANIA )                     C         A
#  (2015A4PS0279G, CHETAN GOUR )                        C
#  (2015A7PS0038G, SHAH SHANAY SUNILBHAI)               B                  B
#  (2015A3PS0283G, RIA S DOSHI )                       A-
#  (2015A4PS0199G, SHUBHAM LAHOTI )                     B        B-
#  (2015A3PS0214G, PARSHVA KOTHARI )                    B         B
#  (2014B4A70782G, MANU SARASWAT )                                        A-
#  (2015A4PS0331G, JAYESH MAHAJAN )                    C-         B
#  (2015A4PS0346G, ALMAAS  TAJ )                        E                  E
#  ...                                                ...       ...      ...
#  (2016A7PS0079G, RAGHAV AGRAWAL)                     A-
#  (2016A1PS0466G, PRACHI TIWARI)                      A-                 A-
#  (2016A7PS0088G, ADITYA BANSAL)                       A
#  (2016A7PS0080G, KESHAV MITTAL)                      B-
#  (2016A7PS0078G, RONAK HARKHANI)                      A
#  (2016A7PS0047G, ISHAAN M PATEL)                     B-
#  (2016A1PS0515G, SHIVAM DUBEY)                       B-                  C
#  (2016A8PS0236G, ISHITA SRIVASTAVA)                  C-
#  (2016A4PS0207G, ANSHUL KUMAR KAUSHAL)               B-
#  (2016A8PS0407G, SANDEEP MISHRA)                     C-
#  (2016A7PS0083G, ISHA)                                B
#  (2016A7PS0046G, MUKUL JAIN)                          A                  B
#  (2016A8PS0389G, MANNAN S JALAN)                      A
#  (2016A3PS0153G, VASU GUPTA)                          C                  C
#  (2016A3B30653G, PUJIKA KUMAR)
#  (2016A8PS0426G, AMAN TAYAL)                         B-
#  (2016A1PS0754G, ASTITVA AGRAWAL)                     B                  C
#  (2016A8PS0270G, ROSHIKA CHATUR)                     B-
#  (2016A8PS0328G, DIKSHANTH)                           A
#  (2016A4PS0317G, SYED UBAID ISHAQ)                   C-
#  (2016A8PS0256G, BHAKTI KHAKKAR)                      B
#  (2016A1PS0529G, VINAY CHHAJER )                      A
#  (2016A3PS0125G, AKSHITA SINGH)                      B-
#  (2016A4PS0233G, Saksham Tambi)                      B-
#  (2016A8PS0350G, SHUBHAM AGRAWAL)                     B
#  (2015A8PS0425G, VASHISHT G ANAND)                    C         C
#  (2015B4PS0586G, MANIKA KANJANI)
#  (2016A8PS0462G, TANISH S SHAH)                       C                  A
#  (2015B2A80819G, PRINCEE S VERMA)                     B                  C
#  (2014B2A40908G, KUNWARJEET CHAWLA)                  A-        A-
#
#  1                                            ECON F241 ECON F312 ECON F355  \
#  (2014B1A40787G, Parth Madan)
#  (2014B5A30789G, Rikkin Majjani)
#  (2014B1A30709G, HEER JOISHER)                        C
#  (2015A1PS0620G, SHIVYAM RASTOGI )
#  (2015A3PS0193G, DEEPANSHU KAUSHIK )
#  (2015B4A70469G, VINEET AGARWAL )
#  (2015A3PS0256G, SAUMYA RAJ )
#  (2015A1PS0643G, AYUSH MITTAL )
#  (2015A1PS0693G, AMANDEEP SINGH )
#  (2015A3PS0248G, AMRITESH KUMAR )
#  (2015A4PS0180G, ADITYA JHA )                                            C-
#  (2015A7PS0103G, LAV VIJAYVARGIYA )                                      B-
#  (2015A8PS0510G, FADNAVIS RUTVIK SHAILENDRA )
#  (2015A7PS0095G, SHILPA RAJU )                       C-
#  (2015A3PS0238G, SHUBHAM SINGLA )
#  (2015A8PS0480G, SHIVANI NEEMA )
#  (2015A3PS0184G, SANSKRITI SHRIVASTAVA )
#  (2015A7PS0099G, SHUBHANK MAHESHWARI )
#  (2015A8PS0392G, VISHAL ASNANI )
#  (2015A7PS0023G, SAMARTH MITTAL )
#  (2015A1PS0684G, RAKTIM ROYCHOUDHURY )
#  (2015A8PS0441G, AKSHAT BUDANIA )                                         B
#  (2015A4PS0279G, CHETAN GOUR )                                  C
#  (2015A7PS0038G, SHAH SHANAY SUNILBHAI)                                  A-
#  (2015A3PS0283G, RIA S DOSHI )
#  (2015A4PS0199G, SHUBHAM LAHOTI )                               D         C
#  (2015A3PS0214G, PARSHVA KOTHARI )
#  (2014B4A70782G, MANU SARASWAT )
#  (2015A4PS0331G, JAYESH MAHAJAN )                                        B-
#  (2015A4PS0346G, ALMAAS  TAJ )
#  ...                                                ...       ...       ...
#  (2016A7PS0079G, RAGHAV AGRAWAL)
#  (2016A1PS0466G, PRACHI TIWARI)
#  (2016A7PS0088G, ADITYA BANSAL)
#  (2016A7PS0080G, KESHAV MITTAL)
#  (2016A7PS0078G, RONAK HARKHANI)
#  (2016A7PS0047G, ISHAAN M PATEL)
#  (2016A1PS0515G, SHIVAM DUBEY)
#  (2016A8PS0236G, ISHITA SRIVASTAVA)
#  (2016A4PS0207G, ANSHUL KUMAR KAUSHAL)
#  (2016A8PS0407G, SANDEEP MISHRA)
#  (2016A7PS0083G, ISHA)
#  (2016A7PS0046G, MUKUL JAIN)
#  (2016A8PS0389G, MANNAN S JALAN)
#  (2016A3PS0153G, VASU GUPTA)                                             C-
#  (2016A3B30653G, PUJIKA KUMAR)
#  (2016A8PS0426G, AMAN TAYAL)
#  (2016A1PS0754G, ASTITVA AGRAWAL)
#  (2016A8PS0270G, ROSHIKA CHATUR)
#  (2016A8PS0328G, DIKSHANTH)
#  (2016A4PS0317G, SYED UBAID ISHAQ)
#  (2016A8PS0256G, BHAKTI KHAKKAR)
#  (2016A1PS0529G, VINAY CHHAJER )
#  (2016A3PS0125G, AKSHITA SINGH)
#  (2016A4PS0233G, Saksham Tambi)                                          A-
#  (2016A8PS0350G, SHUBHAM AGRAWAL)
#  (2015A8PS0425G, VASHISHT G ANAND)
#  (2015B4PS0586G, MANIKA KANJANI)
#  (2016A8PS0462G, TANISH S SHAH)                                          A-
#  (2015B2A80819G, PRINCEE S VERMA)                                         B
#  (2014B2A40908G, KUNWARJEET CHAWLA)
#
#  1                                            ECON F411  ECON F413 FIN F414  \
#  (2014B1A40787G, Parth Madan)                                    C
#  (2014B5A30789G, Rikkin Majjani)                                 A       A-
#  (2014B1A30709G, HEER JOISHER)
#  (2015A1PS0620G, SHIVYAM RASTOGI )                                        A
#  (2015A3PS0193G, DEEPANSHU KAUSHIK )                                      B
#  (2015B4A70469G, VINEET AGARWAL )
#  (2015A3PS0256G, SAUMYA RAJ )
#  (2015A1PS0643G, AYUSH MITTAL )                                           C
#  (2015A1PS0693G, AMANDEEP SINGH )
#  (2015A3PS0248G, AMRITESH KUMAR )                                         C
#  (2015A4PS0180G, ADITYA JHA )
#  (2015A7PS0103G, LAV VIJAYVARGIYA )
#  (2015A8PS0510G, FADNAVIS RUTVIK SHAILENDRA )
#  (2015A7PS0095G, SHILPA RAJU )
#  (2015A3PS0238G, SHUBHAM SINGLA )                                        B-
#  (2015A8PS0480G, SHIVANI NEEMA )                                         B-
#  (2015A3PS0184G, SANSKRITI SHRIVASTAVA )
#  (2015A7PS0099G, SHUBHANK MAHESHWARI )
#  (2015A8PS0392G, VISHAL ASNANI )
#  (2015A7PS0023G, SAMARTH MITTAL )
#  (2015A1PS0684G, RAKTIM ROYCHOUDHURY )                                   B-
#  (2015A8PS0441G, AKSHAT BUDANIA )                                         B
#  (2015A4PS0279G, CHETAN GOUR )
#  (2015A7PS0038G, SHAH SHANAY SUNILBHAI)
#  (2015A3PS0283G, RIA S DOSHI )
#  (2015A4PS0199G, SHUBHAM LAHOTI )
#  (2015A3PS0214G, PARSHVA KOTHARI )                                       A-
#  (2014B4A70782G, MANU SARASWAT )
#  (2015A4PS0331G, JAYESH MAHAJAN )
#  (2015A4PS0346G, ALMAAS  TAJ )
#  ...                                                 ...       ...      ...
#  (2016A7PS0079G, RAGHAV AGRAWAL)
#  (2016A1PS0466G, PRACHI TIWARI)
#  (2016A7PS0088G, ADITYA BANSAL)
#  (2016A7PS0080G, KESHAV MITTAL)
#  (2016A7PS0078G, RONAK HARKHANI)
#  (2016A7PS0047G, ISHAAN M PATEL)
#  (2016A1PS0515G, SHIVAM DUBEY)
#  (2016A8PS0236G, ISHITA SRIVASTAVA)
#  (2016A4PS0207G, ANSHUL KUMAR KAUSHAL)
#  (2016A8PS0407G, SANDEEP MISHRA)
#  (2016A7PS0083G, ISHA)
#  (2016A7PS0046G, MUKUL JAIN)
#  (2016A8PS0389G, MANNAN S JALAN)
#  (2016A3PS0153G, VASU GUPTA)
#  (2016A3B30653G, PUJIKA KUMAR)
#  (2016A8PS0426G, AMAN TAYAL)
#  (2016A1PS0754G, ASTITVA AGRAWAL)
#  (2016A8PS0270G, ROSHIKA CHATUR)
#  (2016A8PS0328G, DIKSHANTH)
#  (2016A4PS0317G, SYED UBAID ISHAQ)
#  (2016A8PS0256G, BHAKTI KHAKKAR)
#  (2016A1PS0529G, VINAY CHHAJER )
#  (2016A3PS0125G, AKSHITA SINGH)
#  (2016A4PS0233G, Saksham Tambi)
#  (2016A8PS0350G, SHUBHAM AGRAWAL)
#  (2015A8PS0425G, VASHISHT G ANAND)                                        C
#  (2015B4PS0586G, MANIKA KANJANI)
#  (2016A8PS0462G, TANISH S SHAH)
#  (2015B2A80819G, PRINCEE S VERMA)
#  (2014B2A40908G, KUNWARJEET CHAWLA)                             B-       C-
#
#  1                                            FIN F242    ...     FIN F313  \
#  (2014B1A40787G, Parth Madan)                             ...            B
#  (2014B5A30789G, Rikkin Majjani)                          ...
#  (2014B1A30709G, HEER JOISHER)                            ...
#  (2015A1PS0620G, SHIVYAM RASTOGI )                        ...            B
#  (2015A3PS0193G, DEEPANSHU KAUSHIK )                      ...           A-
#  (2015B4A70469G, VINEET AGARWAL )                         ...
#  (2015A3PS0256G, SAUMYA RAJ )                             ...
#  (2015A1PS0643G, AYUSH MITTAL )                           ...           C-
#  (2015A1PS0693G, AMANDEEP SINGH )                         ...           C-
#  (2015A3PS0248G, AMRITESH KUMAR )                         ...            B
#  (2015A4PS0180G, ADITYA JHA )                             ...           C-
#  (2015A7PS0103G, LAV VIJAYVARGIYA )                       ...            C
#  (2015A8PS0510G, FADNAVIS RUTVIK SHAILENDRA )             ...
#  (2015A7PS0095G, SHILPA RAJU )                            ...           C-
#  (2015A3PS0238G, SHUBHAM SINGLA )                         ...           A-
#  (2015A8PS0480G, SHIVANI NEEMA )                          ...           B-
#  (2015A3PS0184G, SANSKRITI SHRIVASTAVA )                  ...
#  (2015A7PS0099G, SHUBHANK MAHESHWARI )                    ...
#  (2015A8PS0392G, VISHAL ASNANI )                          ...            B
#  (2015A7PS0023G, SAMARTH MITTAL )                         ...
#  (2015A1PS0684G, RAKTIM ROYCHOUDHURY )                    ...           B-
#  (2015A8PS0441G, AKSHAT BUDANIA )                         ...           A-
#  (2015A4PS0279G, CHETAN GOUR )                            ...           B-
#  (2015A7PS0038G, SHAH SHANAY SUNILBHAI)                   ...
#  (2015A3PS0283G, RIA S DOSHI )                            ...
#  (2015A4PS0199G, SHUBHAM LAHOTI )                         ...            D
#  (2015A3PS0214G, PARSHVA KOTHARI )                        ...            A
#  (2014B4A70782G, MANU SARASWAT )                          ...
#  (2015A4PS0331G, JAYESH MAHAJAN )                         ...
#  (2015A4PS0346G, ALMAAS  TAJ )                            ...
#  ...                                               ...    ...          ...
#  (2016A7PS0079G, RAGHAV AGRAWAL)                          ...
#  (2016A1PS0466G, PRACHI TIWARI)                           ...            B
#  (2016A7PS0088G, ADITYA BANSAL)                           ...
#  (2016A7PS0080G, KESHAV MITTAL)                           ...           B-
#  (2016A7PS0078G, RONAK HARKHANI)                          ...
#  (2016A7PS0047G, ISHAAN M PATEL)                          ...
#  (2016A1PS0515G, SHIVAM DUBEY)                            ...
#  (2016A8PS0236G, ISHITA SRIVASTAVA)                       ...           B-
#  (2016A4PS0207G, ANSHUL KUMAR KAUSHAL)                    ...
#  (2016A8PS0407G, SANDEEP MISHRA)                          ...            B
#  (2016A7PS0083G, ISHA)                                    ...           B-
#  (2016A7PS0046G, MUKUL JAIN)                              ...
#  (2016A8PS0389G, MANNAN S JALAN)                          ...            B
#  (2016A3PS0153G, VASU GUPTA)                              ...
#  (2016A3B30653G, PUJIKA KUMAR)                            ...
#  (2016A8PS0426G, AMAN TAYAL)                              ...
#  (2016A1PS0754G, ASTITVA AGRAWAL)                         ...           B-
#  (2016A8PS0270G, ROSHIKA CHATUR)                          ...           B-
#  (2016A8PS0328G, DIKSHANTH)                               ...            B
#  (2016A4PS0317G, SYED UBAID ISHAQ)                        ...
#  (2016A8PS0256G, BHAKTI KHAKKAR)                          ...            B
#  (2016A1PS0529G, VINAY CHHAJER )                          ...            B
#  (2016A3PS0125G, AKSHITA SINGH)                           ...            B
#  (2016A4PS0233G, Saksham Tambi)                           ...
#  (2016A8PS0350G, SHUBHAM AGRAWAL)                         ...            B
#  (2015A8PS0425G, VASHISHT G ANAND)                        ...           B-
#  (2015B4PS0586G, MANIKA KANJANI)                          ...
#  (2016A8PS0462G, TANISH S SHAH)                           ...           B-
#  (2015B2A80819G, PRINCEE S VERMA)                         ...           B-
#  (2014B2A40908G, KUNWARJEET CHAWLA)                       ...
#
#  1                                            ECON F412 FIN F314  \
#  (2014B1A40787G, Parth Madan)
#  (2014B5A30789G, Rikkin Majjani)                      B
#  (2014B1A30709G, HEER JOISHER)                        B
#  (2015A1PS0620G, SHIVYAM RASTOGI )
#  (2015A3PS0193G, DEEPANSHU KAUSHIK )                  C
#  (2015B4A70469G, VINEET AGARWAL )
#  (2015A3PS0256G, SAUMYA RAJ )
#  (2015A1PS0643G, AYUSH MITTAL )
#  (2015A1PS0693G, AMANDEEP SINGH )
#  (2015A3PS0248G, AMRITESH KUMAR )
#  (2015A4PS0180G, ADITYA JHA )
#  (2015A7PS0103G, LAV VIJAYVARGIYA )
#  (2015A8PS0510G, FADNAVIS RUTVIK SHAILENDRA )
#  (2015A7PS0095G, SHILPA RAJU )
#  (2015A3PS0238G, SHUBHAM SINGLA )
#  (2015A8PS0480G, SHIVANI NEEMA )
#  (2015A3PS0184G, SANSKRITI SHRIVASTAVA )              D
#  (2015A7PS0099G, SHUBHANK MAHESHWARI )
#  (2015A8PS0392G, VISHAL ASNANI )
#  (2015A7PS0023G, SAMARTH MITTAL )
#  (2015A1PS0684G, RAKTIM ROYCHOUDHURY )
#  (2015A8PS0441G, AKSHAT BUDANIA )
#  (2015A4PS0279G, CHETAN GOUR )
#  (2015A7PS0038G, SHAH SHANAY SUNILBHAI)               B
#  (2015A3PS0283G, RIA S DOSHI )
#  (2015A4PS0199G, SHUBHAM LAHOTI )
#  (2015A3PS0214G, PARSHVA KOTHARI )
#  (2014B4A70782G, MANU SARASWAT )                      C
#  (2015A4PS0331G, JAYESH MAHAJAN )
#  (2015A4PS0346G, ALMAAS  TAJ )
#  ...                                                ...      ...
#  (2016A7PS0079G, RAGHAV AGRAWAL)
#  (2016A1PS0466G, PRACHI TIWARI)
#  (2016A7PS0088G, ADITYA BANSAL)
#  (2016A7PS0080G, KESHAV MITTAL)
#  (2016A7PS0078G, RONAK HARKHANI)
#  (2016A7PS0047G, ISHAAN M PATEL)
#  (2016A1PS0515G, SHIVAM DUBEY)
#  (2016A8PS0236G, ISHITA SRIVASTAVA)
#  (2016A4PS0207G, ANSHUL KUMAR KAUSHAL)
#  (2016A8PS0407G, SANDEEP MISHRA)
#  (2016A7PS0083G, ISHA)
#  (2016A7PS0046G, MUKUL JAIN)
#  (2016A8PS0389G, MANNAN S JALAN)
#  (2016A3PS0153G, VASU GUPTA)
#  (2016A3B30653G, PUJIKA KUMAR)
#  (2016A8PS0426G, AMAN TAYAL)
#  (2016A1PS0754G, ASTITVA AGRAWAL)
#  (2016A8PS0270G, ROSHIKA CHATUR)
#  (2016A8PS0328G, DIKSHANTH)
#  (2016A4PS0317G, SYED UBAID ISHAQ)
#  (2016A8PS0256G, BHAKTI KHAKKAR)
#  (2016A1PS0529G, VINAY CHHAJER )
#  (2016A3PS0125G, AKSHITA SINGH)
#  (2016A4PS0233G, Saksham Tambi)
#  (2016A8PS0350G, SHUBHAM AGRAWAL)
#  (2015A8PS0425G, VASHISHT G ANAND)
#  (2015B4PS0586G, MANIKA KANJANI)
#  (2016A8PS0462G, TANISH S SHAH)
#  (2015B2A80819G, PRINCEE S VERMA)
#  (2014B2A40908G, KUNWARJEET CHAWLA)                  B-
#
#  1                                            #REQD_Core_courses  \
#  (2014B1A40787G, Parth Madan)                                2.0
#  (2014B5A30789G, Rikkin Majjani)                             2.0
#  (2014B1A30709G, HEER JOISHER)                               2.0
#  (2015A1PS0620G, SHIVYAM RASTOGI )                           2.0
#  (2015A3PS0193G, DEEPANSHU KAUSHIK )                         2.0
#  (2015B4A70469G, VINEET AGARWAL )                            2.0
#  (2015A3PS0256G, SAUMYA RAJ )                                2.0
#  (2015A1PS0643G, AYUSH MITTAL )                              2.0
#  (2015A1PS0693G, AMANDEEP SINGH )                            2.0
#  (2015A3PS0248G, AMRITESH KUMAR )                            2.0
#  (2015A4PS0180G, ADITYA JHA )                                2.0
#  (2015A7PS0103G, LAV VIJAYVARGIYA )                          2.0
#  (2015A8PS0510G, FADNAVIS RUTVIK SHAILENDRA )                2.0
#  (2015A7PS0095G, SHILPA RAJU )                               2.0
#  (2015A3PS0238G, SHUBHAM SINGLA )                            2.0
#  (2015A8PS0480G, SHIVANI NEEMA )                             2.0
#  (2015A3PS0184G, SANSKRITI SHRIVASTAVA )                     2.0
#  (2015A7PS0099G, SHUBHANK MAHESHWARI )                       2.0
#  (2015A8PS0392G, VISHAL ASNANI )                             2.0
#  (2015A7PS0023G, SAMARTH MITTAL )                            2.0
#  (2015A1PS0684G, RAKTIM ROYCHOUDHURY )                       2.0
#  (2015A8PS0441G, AKSHAT BUDANIA )                            2.0
#  (2015A4PS0279G, CHETAN GOUR )                               2.0
#  (2015A7PS0038G, SHAH SHANAY SUNILBHAI)                      2.0
#  (2015A3PS0283G, RIA S DOSHI )                               2.0
#  (2015A4PS0199G, SHUBHAM LAHOTI )                            2.0
#  (2015A3PS0214G, PARSHVA KOTHARI )                           2.0
#  (2014B4A70782G, MANU SARASWAT )                             2.0
#  (2015A4PS0331G, JAYESH MAHAJAN )                            2.0
#  (2015A4PS0346G, ALMAAS  TAJ )                               2.0
#  ...                                                         ...
#  (2016A7PS0079G, RAGHAV AGRAWAL)                             2.0
#  (2016A1PS0466G, PRACHI TIWARI)                              2.0
#  (2016A7PS0088G, ADITYA BANSAL)                              2.0
#  (2016A7PS0080G, KESHAV MITTAL)                              2.0
#  (2016A7PS0078G, RONAK HARKHANI)                             2.0
#  (2016A7PS0047G, ISHAAN M PATEL)                             2.0
#  (2016A1PS0515G, SHIVAM DUBEY)                               2.0
#  (2016A8PS0236G, ISHITA SRIVASTAVA)                          2.0
#  (2016A4PS0207G, ANSHUL KUMAR KAUSHAL)                       2.0
#  (2016A8PS0407G, SANDEEP MISHRA)                             2.0
#  (2016A7PS0083G, ISHA)                                       2.0
#  (2016A7PS0046G, MUKUL JAIN)                                 2.0
#  (2016A8PS0389G, MANNAN S JALAN)                             2.0
#  (2016A3PS0153G, VASU GUPTA)                                 2.0
#  (2016A3B30653G, PUJIKA KUMAR)                               2.0
#  (2016A8PS0426G, AMAN TAYAL)                                 2.0
#  (2016A1PS0754G, ASTITVA AGRAWAL)                            2.0
#  (2016A8PS0270G, ROSHIKA CHATUR)                             2.0
#  (2016A8PS0328G, DIKSHANTH)                                  2.0
#  (2016A4PS0317G, SYED UBAID ISHAQ)                           2.0
#  (2016A8PS0256G, BHAKTI KHAKKAR)                             2.0
#  (2016A1PS0529G, VINAY CHHAJER )                             2.0
#  (2016A3PS0125G, AKSHITA SINGH)                              2.0
#  (2016A4PS0233G, Saksham Tambi)                              2.0
#  (2016A8PS0350G, SHUBHAM AGRAWAL)                            2.0
#  (2015A8PS0425G, VASHISHT G ANAND)                           2.0
#  (2015B4PS0586G, MANIKA KANJANI)                             2.0
#  (2016A8PS0462G, TANISH S SHAH)                              2.0
#  (2015B2A80819G, PRINCEE S VERMA)                            2.0
#  (2014B2A40908G, KUNWARJEET CHAWLA)                          2.0
#
#  1                                            #REQD_Elective_courses  \
#  (2014B1A40787G, Parth Madan)                                    3.0
#  (2014B5A30789G, Rikkin Majjani)                                 3.0
#  (2014B1A30709G, HEER JOISHER)                                   3.0
#  (2015A1PS0620G, SHIVYAM RASTOGI )                               3.0
#  (2015A3PS0193G, DEEPANSHU KAUSHIK )                             3.0
#  (2015B4A70469G, VINEET AGARWAL )                                3.0
#  (2015A3PS0256G, SAUMYA RAJ )                                    3.0
#  (2015A1PS0643G, AYUSH MITTAL )                                  3.0
#  (2015A1PS0693G, AMANDEEP SINGH )                                3.0
#  (2015A3PS0248G, AMRITESH KUMAR )                                3.0
#  (2015A4PS0180G, ADITYA JHA )                                    3.0
#  (2015A7PS0103G, LAV VIJAYVARGIYA )                              3.0
#  (2015A8PS0510G, FADNAVIS RUTVIK SHAILENDRA )                    3.0
#  (2015A7PS0095G, SHILPA RAJU )                                   3.0
#  (2015A3PS0238G, SHUBHAM SINGLA )                                3.0
#  (2015A8PS0480G, SHIVANI NEEMA )                                 3.0
#  (2015A3PS0184G, SANSKRITI SHRIVASTAVA )                         3.0
#  (2015A7PS0099G, SHUBHANK MAHESHWARI )                           3.0
#  (2015A8PS0392G, VISHAL ASNANI )                                 3.0
#  (2015A7PS0023G, SAMARTH MITTAL )                                3.0
#  (2015A1PS0684G, RAKTIM ROYCHOUDHURY )                           3.0
#  (2015A8PS0441G, AKSHAT BUDANIA )                                3.0
#  (2015A4PS0279G, CHETAN GOUR )                                   3.0
#  (2015A7PS0038G, SHAH SHANAY SUNILBHAI)                          3.0
#  (2015A3PS0283G, RIA S DOSHI )                                   3.0
#  (2015A4PS0199G, SHUBHAM LAHOTI )                                3.0
#  (2015A3PS0214G, PARSHVA KOTHARI )                               3.0
#  (2014B4A70782G, MANU SARASWAT )                                 3.0
#  (2015A4PS0331G, JAYESH MAHAJAN )                                3.0
#  (2015A4PS0346G, ALMAAS  TAJ )                                   3.0
#  ...                                                             ...
#  (2016A7PS0079G, RAGHAV AGRAWAL)                                 3.0
#  (2016A1PS0466G, PRACHI TIWARI)                                  3.0
#  (2016A7PS0088G, ADITYA BANSAL)                                  3.0
#  (2016A7PS0080G, KESHAV MITTAL)                                  3.0
#  (2016A7PS0078G, RONAK HARKHANI)                                 3.0
#  (2016A7PS0047G, ISHAAN M PATEL)                                 3.0
#  (2016A1PS0515G, SHIVAM DUBEY)                                   3.0
#  (2016A8PS0236G, ISHITA SRIVASTAVA)                              3.0
#  (2016A4PS0207G, ANSHUL KUMAR KAUSHAL)                           3.0
#  (2016A8PS0407G, SANDEEP MISHRA)                                 3.0
#  (2016A7PS0083G, ISHA)                                           3.0
#  (2016A7PS0046G, MUKUL JAIN)                                     3.0
#  (2016A8PS0389G, MANNAN S JALAN)                                 3.0
#  (2016A3PS0153G, VASU GUPTA)                                     3.0
#  (2016A3B30653G, PUJIKA KUMAR)                                   3.0
#  (2016A8PS0426G, AMAN TAYAL)                                     3.0
#  (2016A1PS0754G, ASTITVA AGRAWAL)                                3.0
#  (2016A8PS0270G, ROSHIKA CHATUR)                                 3.0
#  (2016A8PS0328G, DIKSHANTH)                                      3.0
#  (2016A4PS0317G, SYED UBAID ISHAQ)                               3.0
#  (2016A8PS0256G, BHAKTI KHAKKAR)                                 3.0
#  (2016A1PS0529G, VINAY CHHAJER )                                 3.0
#  (2016A3PS0125G, AKSHITA SINGH)                                  3.0
#  (2016A4PS0233G, Saksham Tambi)                                  3.0
#  (2016A8PS0350G, SHUBHAM AGRAWAL)                                3.0
#  (2015A8PS0425G, VASHISHT G ANAND)                               3.0
#  (2015B4PS0586G, MANIKA KANJANI)                                 3.0
#  (2016A8PS0462G, TANISH S SHAH)                                  3.0
#  (2015B2A80819G, PRINCEE S VERMA)                                3.0
#  (2014B2A40908G, KUNWARJEET CHAWLA)                              3.0
#
#  1                                            #DONE_Core Courses  \
#  (2014B1A40787G, Parth Madan)                                1.0
#  (2014B5A30789G, Rikkin Majjani)                             1.0
#  (2014B1A30709G, HEER JOISHER)                               1.0
#  (2015A1PS0620G, SHIVYAM RASTOGI )                           1.0
#  (2015A3PS0193G, DEEPANSHU KAUSHIK )                         2.0
#  (2015B4A70469G, VINEET AGARWAL )                            0.0
#  (2015A3PS0256G, SAUMYA RAJ )                                1.0
#  (2015A1PS0643G, AYUSH MITTAL )                              1.0
#  (2015A1PS0693G, AMANDEEP SINGH )                            1.0
#  (2015A3PS0248G, AMRITESH KUMAR )                            1.0
#  (2015A4PS0180G, ADITYA JHA )                                1.0
#  (2015A7PS0103G, LAV VIJAYVARGIYA )                          1.0
#  (2015A8PS0510G, FADNAVIS RUTVIK SHAILENDRA )                1.0
#  (2015A7PS0095G, SHILPA RAJU )                               1.0
#  (2015A3PS0238G, SHUBHAM SINGLA )                            1.0
#  (2015A8PS0480G, SHIVANI NEEMA )                             1.0
#  (2015A3PS0184G, SANSKRITI SHRIVASTAVA )                     1.0
#  (2015A7PS0099G, SHUBHANK MAHESHWARI )                       1.0
#  (2015A8PS0392G, VISHAL ASNANI )                             1.0
#  (2015A7PS0023G, SAMARTH MITTAL )                            0.0
#  (2015A1PS0684G, RAKTIM ROYCHOUDHURY )                       1.0
#  (2015A8PS0441G, AKSHAT BUDANIA )                            1.0
#  (2015A4PS0279G, CHETAN GOUR )                               1.0
#  (2015A7PS0038G, SHAH SHANAY SUNILBHAI)                      1.0
#  (2015A3PS0283G, RIA S DOSHI )                               1.0
#  (2015A4PS0199G, SHUBHAM LAHOTI )                            1.0
#  (2015A3PS0214G, PARSHVA KOTHARI )                           1.0
#  (2014B4A70782G, MANU SARASWAT )                             0.0
#  (2015A4PS0331G, JAYESH MAHAJAN )                            1.0
#  (2015A4PS0346G, ALMAAS  TAJ )                               1.0
#  ...                                                         ...
#  (2016A7PS0079G, RAGHAV AGRAWAL)                             1.0
#  (2016A1PS0466G, PRACHI TIWARI)                              1.0
#  (2016A7PS0088G, ADITYA BANSAL)                              1.0
#  (2016A7PS0080G, KESHAV MITTAL)                              1.0
#  (2016A7PS0078G, RONAK HARKHANI)                             1.0
#  (2016A7PS0047G, ISHAAN M PATEL)                             1.0
#  (2016A1PS0515G, SHIVAM DUBEY)                               1.0
#  (2016A8PS0236G, ISHITA SRIVASTAVA)                          1.0
#  (2016A4PS0207G, ANSHUL KUMAR KAUSHAL)                       1.0
#  (2016A8PS0407G, SANDEEP MISHRA)                             1.0
#  (2016A7PS0083G, ISHA)                                       1.0
#  (2016A7PS0046G, MUKUL JAIN)                                 1.0
#  (2016A8PS0389G, MANNAN S JALAN)                             1.0
#  (2016A3PS0153G, VASU GUPTA)                                 1.0
#  (2016A3B30653G, PUJIKA KUMAR)                               0.0
#  (2016A8PS0426G, AMAN TAYAL)                                 1.0
#  (2016A1PS0754G, ASTITVA AGRAWAL)                            1.0
#  (2016A8PS0270G, ROSHIKA CHATUR)                             1.0
#  (2016A8PS0328G, DIKSHANTH)                                  1.0
#  (2016A4PS0317G, SYED UBAID ISHAQ)                           1.0
#  (2016A8PS0256G, BHAKTI KHAKKAR)                             1.0
#  (2016A1PS0529G, VINAY CHHAJER )                             1.0
#  (2016A3PS0125G, AKSHITA SINGH)                              1.0
#  (2016A4PS0233G, Saksham Tambi)                              1.0
#  (2016A8PS0350G, SHUBHAM AGRAWAL)                            1.0
#  (2015A8PS0425G, VASHISHT G ANAND)                           1.0
#  (2015B4PS0586G, MANIKA KANJANI)                             0.0
#  (2016A8PS0462G, TANISH S SHAH)                              1.0
#  (2015B2A80819G, PRINCEE S VERMA)                            1.0
#  (2014B2A40908G, KUNWARJEET CHAWLA)                          1.0
#
#  1                                            #DONE_Elective Courses  \
#  (2014B1A40787G, Parth Madan)                                    1.0
#  (2014B5A30789G, Rikkin Majjani)                                 2.0
#  (2014B1A30709G, HEER JOISHER)                                   1.0
#  (2015A1PS0620G, SHIVYAM RASTOGI )                               1.0
#  (2015A3PS0193G, DEEPANSHU KAUSHIK )                             1.0
#  (2015B4A70469G, VINEET AGARWAL )                                0.0
#  (2015A3PS0256G, SAUMYA RAJ )                                    0.0
#  (2015A1PS0643G, AYUSH MITTAL )                                  1.0
#  (2015A1PS0693G, AMANDEEP SINGH )                                0.0
#  (2015A3PS0248G, AMRITESH KUMAR )                                1.0
#  (2015A4PS0180G, ADITYA JHA )                                    1.0
#  (2015A7PS0103G, LAV VIJAYVARGIYA )                              1.0
#  (2015A8PS0510G, FADNAVIS RUTVIK SHAILENDRA )                    0.0
#  (2015A7PS0095G, SHILPA RAJU )                                   1.0
#  (2015A3PS0238G, SHUBHAM SINGLA )                                1.0
#  (2015A8PS0480G, SHIVANI NEEMA )                                 1.0
#  (2015A3PS0184G, SANSKRITI SHRIVASTAVA )                         0.0
#  (2015A7PS0099G, SHUBHANK MAHESHWARI )                           0.0
#  (2015A8PS0392G, VISHAL ASNANI )                                 0.0
#  (2015A7PS0023G, SAMARTH MITTAL )                                0.0
#  (2015A1PS0684G, RAKTIM ROYCHOUDHURY )                           1.0
#  (2015A8PS0441G, AKSHAT BUDANIA )                                2.0
#  (2015A4PS0279G, CHETAN GOUR )                                   1.0
#  (2015A7PS0038G, SHAH SHANAY SUNILBHAI)                          1.0
#  (2015A3PS0283G, RIA S DOSHI )                                   0.0
#  (2015A4PS0199G, SHUBHAM LAHOTI )                                2.0
#  (2015A3PS0214G, PARSHVA KOTHARI )                               1.0
#  (2014B4A70782G, MANU SARASWAT )                                 0.0
#  (2015A4PS0331G, JAYESH MAHAJAN )                                1.0
#  (2015A4PS0346G, ALMAAS  TAJ )                                   0.0
#  ...                                                             ...
#  (2016A7PS0079G, RAGHAV AGRAWAL)                                 0.0
#  (2016A1PS0466G, PRACHI TIWARI)                                  0.0
#  (2016A7PS0088G, ADITYA BANSAL)                                  0.0
#  (2016A7PS0080G, KESHAV MITTAL)                                  0.0
#  (2016A7PS0078G, RONAK HARKHANI)                                 0.0
#  (2016A7PS0047G, ISHAAN M PATEL)                                 0.0
#  (2016A1PS0515G, SHIVAM DUBEY)                                   0.0
#  (2016A8PS0236G, ISHITA SRIVASTAVA)                              0.0
#  (2016A4PS0207G, ANSHUL KUMAR KAUSHAL)                           0.0
#  (2016A8PS0407G, SANDEEP MISHRA)                                 0.0
#  (2016A7PS0083G, ISHA)                                           0.0
#  (2016A7PS0046G, MUKUL JAIN)                                     0.0
#  (2016A8PS0389G, MANNAN S JALAN)                                 0.0
#  (2016A3PS0153G, VASU GUPTA)                                     1.0
#  (2016A3B30653G, PUJIKA KUMAR)                                   0.0
#  (2016A8PS0426G, AMAN TAYAL)                                     0.0
#  (2016A1PS0754G, ASTITVA AGRAWAL)                                0.0
#  (2016A8PS0270G, ROSHIKA CHATUR)                                 0.0
#  (2016A8PS0328G, DIKSHANTH)                                      0.0
#  (2016A4PS0317G, SYED UBAID ISHAQ)                               0.0
#  (2016A8PS0256G, BHAKTI KHAKKAR)                                 0.0
#  (2016A1PS0529G, VINAY CHHAJER )                                 0.0
#  (2016A3PS0125G, AKSHITA SINGH)                                  0.0
#  (2016A4PS0233G, Saksham Tambi)                                  1.0
#  (2016A8PS0350G, SHUBHAM AGRAWAL)                                0.0
#  (2015A8PS0425G, VASHISHT G ANAND)                               1.0
#  (2015B4PS0586G, MANIKA KANJANI)                                 0.0
#  (2016A8PS0462G, TANISH S SHAH)                                  1.0
#  (2015B2A80819G, PRINCEE S VERMA)                                1.0
#  (2014B2A40908G, KUNWARJEET CHAWLA)                              2.0
#
#  1                                            #REMAINING_Core_Courses  \
#  (2014B1A40787G, Parth Madan)                                     1.0
#  (2014B5A30789G, Rikkin Majjani)                                  1.0
#  (2014B1A30709G, HEER JOISHER)                                    1.0
#  (2015A1PS0620G, SHIVYAM RASTOGI )                                1.0
#  (2015A3PS0193G, DEEPANSHU KAUSHIK )                              0.0
#  (2015B4A70469G, VINEET AGARWAL )                                 2.0
#  (2015A3PS0256G, SAUMYA RAJ )                                     1.0
#  (2015A1PS0643G, AYUSH MITTAL )                                   1.0
#  (2015A1PS0693G, AMANDEEP SINGH )                                 1.0
#  (2015A3PS0248G, AMRITESH KUMAR )                                 1.0
#  (2015A4PS0180G, ADITYA JHA )                                     1.0
#  (2015A7PS0103G, LAV VIJAYVARGIYA )                               1.0
#  (2015A8PS0510G, FADNAVIS RUTVIK SHAILENDRA )                     1.0
#  (2015A7PS0095G, SHILPA RAJU )                                    1.0
#  (2015A3PS0238G, SHUBHAM SINGLA )                                 1.0
#  (2015A8PS0480G, SHIVANI NEEMA )                                  1.0
#  (2015A3PS0184G, SANSKRITI SHRIVASTAVA )                          1.0
#  (2015A7PS0099G, SHUBHANK MAHESHWARI )                            1.0
#  (2015A8PS0392G, VISHAL ASNANI )                                  1.0
#  (2015A7PS0023G, SAMARTH MITTAL )                                 2.0
#  (2015A1PS0684G, RAKTIM ROYCHOUDHURY )                            1.0
#  (2015A8PS0441G, AKSHAT BUDANIA )                                 1.0
#  (2015A4PS0279G, CHETAN GOUR )                                    1.0
#  (2015A7PS0038G, SHAH SHANAY SUNILBHAI)                           1.0
#  (2015A3PS0283G, RIA S DOSHI )                                    1.0
#  (2015A4PS0199G, SHUBHAM LAHOTI )                                 1.0
#  (2015A3PS0214G, PARSHVA KOTHARI )                                1.0
#  (2014B4A70782G, MANU SARASWAT )                                  2.0
#  (2015A4PS0331G, JAYESH MAHAJAN )                                 1.0
#  (2015A4PS0346G, ALMAAS  TAJ )                                    1.0
#  ...                                                              ...
#  (2016A7PS0079G, RAGHAV AGRAWAL)                                  1.0
#  (2016A1PS0466G, PRACHI TIWARI)                                   1.0
#  (2016A7PS0088G, ADITYA BANSAL)                                   1.0
#  (2016A7PS0080G, KESHAV MITTAL)                                   1.0
#  (2016A7PS0078G, RONAK HARKHANI)                                  1.0
#  (2016A7PS0047G, ISHAAN M PATEL)                                  1.0
#  (2016A1PS0515G, SHIVAM DUBEY)                                    1.0
#  (2016A8PS0236G, ISHITA SRIVASTAVA)                               1.0
#  (2016A4PS0207G, ANSHUL KUMAR KAUSHAL)                            1.0
#  (2016A8PS0407G, SANDEEP MISHRA)                                  1.0
#  (2016A7PS0083G, ISHA)                                            1.0
#  (2016A7PS0046G, MUKUL JAIN)                                      1.0
#  (2016A8PS0389G, MANNAN S JALAN)                                  1.0
#  (2016A3PS0153G, VASU GUPTA)                                      1.0
#  (2016A3B30653G, PUJIKA KUMAR)                                    2.0
#  (2016A8PS0426G, AMAN TAYAL)                                      1.0
#  (2016A1PS0754G, ASTITVA AGRAWAL)                                 1.0
#  (2016A8PS0270G, ROSHIKA CHATUR)                                  1.0
#  (2016A8PS0328G, DIKSHANTH)                                       1.0
#  (2016A4PS0317G, SYED UBAID ISHAQ)                                1.0
#  (2016A8PS0256G, BHAKTI KHAKKAR)                                  1.0
#  (2016A1PS0529G, VINAY CHHAJER )                                  1.0
#  (2016A3PS0125G, AKSHITA SINGH)                                   1.0
#  (2016A4PS0233G, Saksham Tambi)                                   1.0
#  (2016A8PS0350G, SHUBHAM AGRAWAL)                                 1.0
#  (2015A8PS0425G, VASHISHT G ANAND)                                1.0
#  (2015B4PS0586G, MANIKA KANJANI)                                  2.0
#  (2016A8PS0462G, TANISH S SHAH)                                   1.0
#  (2015B2A80819G, PRINCEE S VERMA)                                 1.0
#  (2014B2A40908G, KUNWARJEET CHAWLA)                               1.0
#
#  1                                             #REMAINING_Elective Courses  \
#  (2014B1A40787G, Parth Madan)                                          2.0
#  (2014B5A30789G, Rikkin Majjani)                                       1.0
#  (2014B1A30709G, HEER JOISHER)                                         2.0
#  (2015A1PS0620G, SHIVYAM RASTOGI )                                     2.0
#  (2015A3PS0193G, DEEPANSHU KAUSHIK )                                   2.0
#  (2015B4A70469G, VINEET AGARWAL )                                      3.0
#  (2015A3PS0256G, SAUMYA RAJ )                                          3.0
#  (2015A1PS0643G, AYUSH MITTAL )                                        2.0
#  (2015A1PS0693G, AMANDEEP SINGH )                                      3.0
#  (2015A3PS0248G, AMRITESH KUMAR )                                      2.0
#  (2015A4PS0180G, ADITYA JHA )                                          2.0
#  (2015A7PS0103G, LAV VIJAYVARGIYA )                                    2.0
#  (2015A8PS0510G, FADNAVIS RUTVIK SHAILENDRA )                          3.0
#  (2015A7PS0095G, SHILPA RAJU )                                         2.0
#  (2015A3PS0238G, SHUBHAM SINGLA )                                      2.0
#  (2015A8PS0480G, SHIVANI NEEMA )                                       2.0
#  (2015A3PS0184G, SANSKRITI SHRIVASTAVA )                               3.0
#  (2015A7PS0099G, SHUBHANK MAHESHWARI )                                 3.0
#  (2015A8PS0392G, VISHAL ASNANI )                                       3.0
#  (2015A7PS0023G, SAMARTH MITTAL )                                      3.0
#  (2015A1PS0684G, RAKTIM ROYCHOUDHURY )                                 2.0
#  (2015A8PS0441G, AKSHAT BUDANIA )                                      1.0
#  (2015A4PS0279G, CHETAN GOUR )                                         2.0
#  (2015A7PS0038G, SHAH SHANAY SUNILBHAI)                                2.0
#  (2015A3PS0283G, RIA S DOSHI )                                         3.0
#  (2015A4PS0199G, SHUBHAM LAHOTI )                                      1.0
#  (2015A3PS0214G, PARSHVA KOTHARI )                                     2.0
#  (2014B4A70782G, MANU SARASWAT )                                       3.0
#  (2015A4PS0331G, JAYESH MAHAJAN )                                      2.0
#  (2015A4PS0346G, ALMAAS  TAJ )                                         3.0
#  ...                                                                   ...
#  (2016A7PS0079G, RAGHAV AGRAWAL)                                       3.0
#  (2016A1PS0466G, PRACHI TIWARI)                                        3.0
#  (2016A7PS0088G, ADITYA BANSAL)                                        3.0
#  (2016A7PS0080G, KESHAV MITTAL)                                        3.0
#  (2016A7PS0078G, RONAK HARKHANI)                                       3.0
#  (2016A7PS0047G, ISHAAN M PATEL)                                       3.0
#  (2016A1PS0515G, SHIVAM DUBEY)                                         3.0
#  (2016A8PS0236G, ISHITA SRIVASTAVA)                                    3.0
#  (2016A4PS0207G, ANSHUL KUMAR KAUSHAL)                                 3.0
#  (2016A8PS0407G, SANDEEP MISHRA)                                       3.0
#  (2016A7PS0083G, ISHA)                                                 3.0
#  (2016A7PS0046G, MUKUL JAIN)                                           3.0
#  (2016A8PS0389G, MANNAN S JALAN)                                       3.0
#  (2016A3PS0153G, VASU GUPTA)                                           2.0
#  (2016A3B30653G, PUJIKA KUMAR)                                         3.0
#  (2016A8PS0426G, AMAN TAYAL)                                           3.0
#  (2016A1PS0754G, ASTITVA AGRAWAL)                                      3.0
#  (2016A8PS0270G, ROSHIKA CHATUR)                                       3.0
#  (2016A8PS0328G, DIKSHANTH)                                            3.0
#  (2016A4PS0317G, SYED UBAID ISHAQ)                                     3.0
#  (2016A8PS0256G, BHAKTI KHAKKAR)                                       3.0
#  (2016A1PS0529G, VINAY CHHAJER )                                       3.0
#  (2016A3PS0125G, AKSHITA SINGH)                                        3.0
#  (2016A4PS0233G, Saksham Tambi)                                        2.0
#  (2016A8PS0350G, SHUBHAM AGRAWAL)                                      3.0
#  (2015A8PS0425G, VASHISHT G ANAND)                                     2.0
#  (2015B4PS0586G, MANIKA KANJANI)                                       3.0
#  (2016A8PS0462G, TANISH S SHAH)                                        2.0
#  (2015B2A80819G, PRINCEE S VERMA)                                      2.0
#  (2014B2A40908G, KUNWARJEET CHAWLA)                                    1.0
#
#  1                                                    CG
#  (2014B1A40787G, Parth Madan)                   7.000000
#  (2014B5A30789G, Rikkin Majjani)                9.333333
#  (2014B1A30709G, HEER JOISHER)                  8.000000
#  (2015A1PS0620G, SHIVYAM RASTOGI )              9.500000
#  (2015A3PS0193G, DEEPANSHU KAUSHIK )            6.666667
#  (2015B4A70469G, VINEET AGARWAL )               0.000000
#  (2015A3PS0256G, SAUMYA RAJ )                   9.000000
#  (2015A1PS0643G, AYUSH MITTAL )                 7.000000
#  (2015A1PS0693G, AMANDEEP SINGH )               6.000000
#  (2015A3PS0248G, AMRITESH KUMAR )               6.500000
#  (2015A4PS0180G, ADITYA JHA )                   7.000000
#  (2015A7PS0103G, LAV VIJAYVARGIYA )             8.000000
#  (2015A8PS0510G, FADNAVIS RUTVIK SHAILENDRA )   6.000000
#  (2015A7PS0095G, SHILPA RAJU )                  5.500000
#  (2015A3PS0238G, SHUBHAM SINGLA )               8.000000
#  (2015A8PS0480G, SHIVANI NEEMA )                7.500000
#  (2015A3PS0184G, SANSKRITI SHRIVASTAVA )        6.000000
#  (2015A7PS0099G, SHUBHANK MAHESHWARI )          8.000000
#  (2015A8PS0392G, VISHAL ASNANI )                6.000000
#  (2015A7PS0023G, SAMARTH MITTAL )               0.000000
#  (2015A1PS0684G, RAKTIM ROYCHOUDHURY )          6.500000
#  (2015A8PS0441G, AKSHAT BUDANIA )               7.333333
#  (2015A4PS0279G, CHETAN GOUR )                  6.000000
#  (2015A7PS0038G, SHAH SHANAY SUNILBHAI)         8.500000
#  (2015A3PS0283G, RIA S DOSHI )                  9.000000
#  (2015A4PS0199G, SHUBHAM LAHOTI )               6.000000
#  (2015A3PS0214G, PARSHVA KOTHARI )              8.500000
#  (2014B4A70782G, MANU SARASWAT )                0.000000
#  (2015A4PS0331G, JAYESH MAHAJAN )               6.000000
#  (2015A4PS0346G, ALMAAS  TAJ )                  2.000000
#  ...                                                 ...
#  (2016A7PS0079G, RAGHAV AGRAWAL)                9.000000
#  (2016A1PS0466G, PRACHI TIWARI)                 9.000000
#  (2016A7PS0088G, ADITYA BANSAL)                10.000000
#  (2016A7PS0080G, KESHAV MITTAL)                 7.000000
#  (2016A7PS0078G, RONAK HARKHANI)               10.000000
#  (2016A7PS0047G, ISHAAN M PATEL)                7.000000
#  (2016A1PS0515G, SHIVAM DUBEY)                  7.000000
#  (2016A8PS0236G, ISHITA SRIVASTAVA)             5.000000
#  (2016A4PS0207G, ANSHUL KUMAR KAUSHAL)          7.000000
#  (2016A8PS0407G, SANDEEP MISHRA)                5.000000
#  (2016A7PS0083G, ISHA)                          8.000000
#  (2016A7PS0046G, MUKUL JAIN)                   10.000000
#  (2016A8PS0389G, MANNAN S JALAN)               10.000000
#  (2016A3PS0153G, VASU GUPTA)                    5.500000
#  (2016A3B30653G, PUJIKA KUMAR)                  0.000000
#  (2016A8PS0426G, AMAN TAYAL)                    7.000000
#  (2016A1PS0754G, ASTITVA AGRAWAL)               8.000000
#  (2016A8PS0270G, ROSHIKA CHATUR)                7.000000
#  (2016A8PS0328G, DIKSHANTH)                    10.000000
#  (2016A4PS0317G, SYED UBAID ISHAQ)              5.000000
#  (2016A8PS0256G, BHAKTI KHAKKAR)                8.000000
#  (2016A1PS0529G, VINAY CHHAJER )               10.000000
#  (2016A3PS0125G, AKSHITA SINGH)                 7.000000
#  (2016A4PS0233G, Saksham Tambi)                 8.000000
#  (2016A8PS0350G, SHUBHAM AGRAWAL)               8.000000
#  (2015A8PS0425G, VASHISHT G ANAND)              6.000000
#  (2015B4PS0586G, MANIKA KANJANI)                0.000000
#  (2016A8PS0462G, TANISH S SHAH)                 7.500000
#  (2015B2A80819G, PRINCEE S VERMA)               8.000000
#  (2014B2A40908G, KUNWARJEET CHAWLA)             7.000000
#
#  [118 rows x 25 columns],
#                  ID                         Name
#  23   2014B1A40787G                  Parth Madan
#  24   2014B5A30789G               Rikkin Majjani
#  25   2014B1A30709G                 HEER JOISHER
#  26   2015A1PS0620G             SHIVYAM RASTOGI
#  27   2015A3PS0193G           DEEPANSHU KAUSHIK
#  28   2015B4A70469G              VINEET AGARWAL
#  29   2015A3PS0256G                  SAUMYA RAJ
#  30   2015A1PS0643G                AYUSH MITTAL
#  31   2015A1PS0693G              AMANDEEP SINGH
#  32   2015A3PS0248G              AMRITESH KUMAR
#  33   2015A4PS0180G                  ADITYA JHA
#  34   2015A7PS0103G            LAV VIJAYVARGIYA
#  35   2015A8PS0510G  FADNAVIS RUTVIK SHAILENDRA
#  36   2015A7PS0095G                 SHILPA RAJU
#  37   2015A3PS0238G              SHUBHAM SINGLA
#  38   2015A8PS0480G               SHIVANI NEEMA
#  39   2015A3PS0184G       SANSKRITI SHRIVASTAVA
#  40   2015A7PS0099G         SHUBHANK MAHESHWARI
#  41   2015A8PS0392G               VISHAL ASNANI
#  42   2015A7PS0023G              SAMARTH MITTAL
#  43   2015A1PS0684G         RAKTIM ROYCHOUDHURY
#  44   2015A8PS0441G              AKSHAT BUDANIA
#  45   2015A4PS0279G                 CHETAN GOUR
#  46   2015A7PS0038G        SHAH SHANAY SUNILBHAI
#  47   2015A3PS0283G                 RIA S DOSHI
#  48   2015A4PS0199G              SHUBHAM LAHOTI
#  49   2015A3PS0214G             PARSHVA KOTHARI
#  50   2014B4A70782G               MANU SARASWAT
#  51   2015A4PS0331G              JAYESH MAHAJAN
#  52   2015A4PS0346G                 ALMAAS  TAJ
#  ..             ...                          ...
#  111  2016A7PS0079G               RAGHAV AGRAWAL
#  112  2016A1PS0466G                PRACHI TIWARI
#  113  2016A7PS0088G                ADITYA BANSAL
#  114  2016A7PS0080G                KESHAV MITTAL
#  115  2016A7PS0078G               RONAK HARKHANI
#  116  2016A7PS0047G               ISHAAN M PATEL
#  117  2016A1PS0515G                 SHIVAM DUBEY
#  118  2016A8PS0236G            ISHITA SRIVASTAVA
#  119  2016A4PS0207G         ANSHUL KUMAR KAUSHAL
#  120  2016A8PS0407G               SANDEEP MISHRA
#  121  2016A7PS0083G                         ISHA
#  122  2016A7PS0046G                   MUKUL JAIN
#  123  2016A8PS0389G               MANNAN S JALAN
#  124  2016A3PS0153G                   VASU GUPTA
#  125  2016A3B30653G                 PUJIKA KUMAR
#  126  2016A8PS0426G                   AMAN TAYAL
#  127  2016A1PS0754G              ASTITVA AGRAWAL
#  128  2016A8PS0270G               ROSHIKA CHATUR
#  129  2016A8PS0328G                    DIKSHANTH
#  130  2016A4PS0317G             SYED UBAID ISHAQ
#  131  2016A8PS0256G               BHAKTI KHAKKAR
#  132  2016A1PS0529G               VINAY CHHAJER
#  133  2016A3PS0125G                AKSHITA SINGH
#  134  2016A4PS0233G                Saksham Tambi
#  135  2016A8PS0350G              SHUBHAM AGRAWAL
#  136  2015A8PS0425G             VASHISHT G ANAND
#  137  2015B4PS0586G               MANIKA KANJANI
#  138  2016A8PS0462G                TANISH S SHAH
#  139  2015B2A80819G              PRINCEE S VERMA
#  140  2014B2A40908G            KUNWARJEET CHAWLA
#
#  [118 rows x 2 columns])

# %%
def load_files():
    from os import listdir
    from os.path import isfile, join

    files = [f for f in listdir("./data") if isfile(join("./data", f))]
    files.sort()
    files
    registration_data=pd.DataFrame()
    for i in files:
        data = pd.read_excel("./data/"+i,"sheet1",header=1)
        registration_data=registration_data.append(data)
    return registration_data

# %%
def units():
    excel_file = 'units.xls'
    units = pd.read_excel(excel_file,header=None)
    unit_dic=dict(zip(units[0],units[2]))
    return unit_dic

# %%
def minor_load(degree):
        ############ Store Students in each minor course ###############
    
    minor_students=pd.read_excel("Minor Student list.xls",header=None)
    minor_students.columns=['ID','Name',"Minor"]
    #minor_students
    
    degree_students= minor_students.ix[(minor_students['Minor']== degree +' Minor'), ['ID','Name']]
    #print("sdfio",degree_students)
    CGPA_create(degree_students) 
    #print(minor_students)
    #print(degree_students)
    
    
    degree_courses=pd.read_csv(degree+".csv",header=None)
    degree_courses.rows=['Core/Elective','Course No',"Equivalent","Pair No"]
    
    #degree_courses
    
    
    registration_data=load_files()
    #registration_data=['Core/Elective','Course No',"Equivalent","Pair No"]
    registration_data["Course"] = registration_data["Subject"]+" "+registration_data["Catalog No."]

    #registration_data 
    #print(registration_data)
    return degree_students,degree_courses,registration_data

# %%
def CGPA_create(students):
    students=students.values.tolist()
    #print(np.hape(students))
    global CGPA_courses
    for i in range(len(students)):
        temp=[]
        temp.append(students[i][0])
        CGPA_courses.append(temp)
    #print(CGPA_courses)
    
#minor_load("Finance")

# %%
def CGPA(degree,degree_data):
    grade_dic={"A":10,"A-":9,"B":8,"B-":7,"C":6,"C-":5,"D":4,"E":2}
    
    #var represtes total number of courses to be considered for CG of that particular degree
    var=6
    if(degree=='PEP'):
        var=7
    for i in range(len(CGPA_courses)):
        grades_done=0;
        total_units=0;
        for j in range(1,len(CGPA_courses[i])):
            if (j==var):
                break
            units=unit_dic(CGPA_courses[i][j])
            grade=degree_data.at[i, CGPA_courses[i][j]]
            grades_done+=grade_dic()
# Out:
#   File "<ipython-input-28-ab08fd6f4617>", line 1
#     def CGPA():
#                ^
# SyntaxError: unexpected EOF while parsing

# %%
degree_data = pd.DataFrame(data=' ',index=degree_students,columns=degree_courses.T[1])
    global CGPA_courses
    # print(degree_data)
    for i,data in degree_data.iterrows():
        student_id = i[0]
        student=registration_data.loc[((registration_data["Campus ID"])== (student_id))]
        for course in degree_courses.iloc[1]:
            if course in student["Course"].values:
                grade=student.loc[(student["Course"])==course]["Course Grade"].values
                if not(grade[0]=='W' or grade[0]=='NC'):
                    for a in range(len(CGPA_courses)):
                        if (CGPA_courses[a][0]==student_id):
                            if(course not in CGPA_courses[a]):
                                CGPA_courses[a].append(course)
                    
                #finance_data[student][course]=grade
                if(degree_data.at[i, course] != None):
                    if not(grade[0]=='W' or grade[0]=='NC'):
                        degree_data.at[i, course] = grade[0]
                else:
                    degree_data.at[i, course] = grade[0]
                    
                #df[df.Letters=='C'].Letters.item()

#?degree_data
    #print(CGPA_courses)
    
    unit_dic=units()
    
    grade_dic={"A":10,"A-":9,"B":8,"B-":7,"C":6,"C-":5,"D":4,"E":2}

    for i,data in degree_data.iterrows():
        student_id=i[0]
        core_courses=0
        elective_courses=0
        total_credits=0
        total_grade=0
        equivalent_done = []
        #student.loc[(student["Course"])==course]["Course Grade"].values
        for temp,course in enumerate(degree_courses.iloc[1]):
            course_grade=degree_data.at[i, course]
            if (degree_courses.at[2,temp]=="No" and (course_grade in grade_dic.keys())):
                if(degree_courses.at[0,temp]=="Core"):
                    core_courses+=1
                    total_credits+=unit_dic[course]
                    total_grade+=unit_dic[course]*grade_dic[course_grade]                
                elif (degree_courses.at[0,temp]=="Elective"):
                    elective_courses+=1
                    total_credits+=unit_dic[course]
                    total_grade+=unit_dic[course]*grade_dic[course_grade]
            elif (degree_courses.at[2,temp]=="Yes" and (course_grade in grade_dic.keys())):
                if(degree_courses.at[3,temp] in equivalent_done):
                    continue
                for tempcourseno,details in degree_courses.iteritems():
                    if(tempcourseno!=temp and details[3]==degree_courses.at[3,temp]):
                        tempcoursegrade = degree_data.at[i, details[1]]
                        if (tempcoursegrade in grade_dic.keys()):
                            equivalent_done += [details[3]]
                            finalgrade = max(grade_dic[course_grade], grade_dic[tempcoursegrade])
                            core_courses+=1
#                             total_credits+=unit_dic[course]
#                             total_grade+=finalgrade

#         if(total_credits>0):
#             cg=total_grade/total_credits        
#         else:
#             cg=0
            
        if(degree=='PEP'):
            a=3
            b=3
        elif(degree=='Physics'):
            a=3
            b=2
        elif(degree=='English'):
            a=2
            b=3
        elif(degree=='Finance'):
            a=2
            b=3
        else:
            a=2
            b=3
            
        degree_data.at[i, "#REQD_Core_courses"] = a
        degree_data.at[i, "#REQD_Elective_courses"] = b

        degree_data.at[i, "#DONE_Core Courses"] = core_courses
        degree_data.at[i, "#DONE_Elective Courses"] = elective_courses

        degree_data.at[i, "#REMAINING_Core_Courses"] = degree_data.at[i, "#REQD_Core_courses"]-degree_data.at[i, "#DONE_Core Courses"]
        degree_data.at[i, "#REMAINING_Elective Courses"] = degree_data.at[i, "#REQD_Elective_courses"]-degree_data.at[i, "#DONE_Elective Courses"]

#         degree_data.at[i, "CG"] = cg
        #print(core_courses,elective_courses,cg)  

        # print(degree_data)
    return degree_data

# %%
def minor_write(degreearr,degree_dataarr,n):
    with pd.ExcelWriter('Minor_Data.xlsx') as writer: 
        workbook  = writer.book
        header_format = workbook.add_format({
        'bold': True,
        'text_wrap': True,
        'valign': 'top',
        'fg_color': '#48ceca',
        'border': 1})

        for i in range(n):
            # print(degree_dataarr[i])
            degree_dataarr[i].to_excel(writer, sheet_name=degreearr[i]+" Minor",startcol=1,startrow=2)
            worksheet = writer.sheets[degreearr[i]+' Minor']
            worksheet.write( 2,0, "ID NO", header_format)
            worksheet.write( 2,1, "NAME", header_format)
            for row_num, value in enumerate(degree_dataarr[i].index.values):
                worksheet.write( row_num + 3,0, value[0], header_format)
                worksheet.write( row_num + 3,1, value[1], header_format)

# %%
def main(degree):
    degree_students,degree_courses,registration_data=minor_load(degree)
    degree_students_cp=degree_students
    degree_data1=minor_main(degree,degree_students,degree_courses,registration_data)
    #print(degree_data1)
    return degree,degree_data1,degree_students

# %%
import sys
lell=len(sys.argv)
degreearr=[]
degree_dataarr = []
for i in range(1,lell):
    CGPA_courses=[]
    degree,degree_data,degree_students = main(sys.argv[i])
    CGPA(degree,degree_data)
    degreearr.append(degree)
    degree_dataarr.append(degree_data)
    #degreestudnts=CGPA_courses(degree_students)

minor_write(degreearr,degree_dataarr,lell-1)
# Out:
# /home/vinayak/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:8: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-10-297e3b096777> in <module>()
#       5 for i in range(1,lell):
#       6     CGPA_courses=[]
# ----> 7     degree,degree_data,degree_students = main(sys.argv[i])
#       8     degreearr.append(degree)
#       9     degree_dataarr.append(degree_data)
#
# <ipython-input-9-163c618ce6d4> in main(degree)
#       1 def main(degree):
# ----> 2     degree_students,degree_courses,registration_data=minor_load(degree)
#       3     degree_students_cp=degree_students
#       4     degree_data1=minor_main(degree,degree_students,degree_courses,registration_data)
#       5     #print(degree_data1)
#
# <ipython-input-6-aeaa26dd2f08> in minor_load(degree)
#      13
#      14
# ---> 15     degree_courses=pd.read_csv(degree+".csv",header=None)
#      16     degree_courses.rows=['Core/Elective','Course No',"Equivalent","Pair No"]
#      17
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/io/parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, escapechar, comment, encoding, dialect, tupleize_cols, error_bad_lines, warn_bad_lines, skipfooter, skip_footer, doublequote, delim_whitespace, as_recarray, compact_ints, use_unsigned, low_memory, buffer_lines, memory_map, float_precision)
#     653                     skip_blank_lines=skip_blank_lines)
#     654
# --> 655         return _read(filepath_or_buffer, kwds)
#     656
#     657     parser_f.__name__ = name
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/io/parsers.py in _read(filepath_or_buffer, kwds)
#     403
#     404     # Create the parser.
# --> 405     parser = TextFileReader(filepath_or_buffer, **kwds)
#     406
#     407     if chunksize or iterator:
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/io/parsers.py in __init__(self, f, engine, **kwds)
#     762             self.options['has_index_names'] = kwds['has_index_names']
#     763
# --> 764         self._make_engine(self.engine)
#     765
#     766     def close(self):
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/io/parsers.py in _make_engine(self, engine)
#     983     def _make_engine(self, engine='c'):
#     984         if engine == 'c':
# --> 985             self._engine = CParserWrapper(self.f, **self.options)
#     986         else:
#     987             if engine == 'python':
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/io/parsers.py in __init__(self, src, **kwds)
#    1603         kwds['allow_leading_cols'] = self.index_col is not False
#    1604
# -> 1605         self._reader = parsers.TextReader(src, **kwds)
#    1606
#    1607         # XXX
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader.__cinit__ (pandas/_libs/parsers.c:4209)()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._setup_parser_source (pandas/_libs/parsers.c:8873)()
#
# FileNotFoundError: File b'-f.csv' does not exist
